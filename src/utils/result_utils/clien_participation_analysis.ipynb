# %%
import h5py
import numpy as np
import pandas as pd 
import os
import numpy as np
import re
import csv
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
def convert_csv_to_txt(input_file,output_file):
   
    with open(input_file, 'r') as csv_file, open(output_file, 'w') as space_delimited_file:
        csv_reader = csv.reader(csv_file)
        for row in csv_reader:
            space_delimited_file.write(' '.join(row) + '\n')

    print(f'CSV file "{input_file}" converted to space-delimited file "{output_file}"')

# %%
def read_file(file):
    hf = h5py.File(file, 'r')
    attributes = []
    for key in hf.keys():
        attributes.append(key)
    
    return attributes, hf

# %%
def get_data(hf,attributes):
    data = []
    pm = []
    acc_pm = []
    loss_pm = []
    loss_gm = []
    for i in range(len(attributes)):
        ai = hf.get(attributes[i])
        ai = np.array(ai)
        data.append(ai)
    
    return data

# %%
def plot_convergence(client_part_8_test_loss,
                    client_part_8_test_accuracy,
                    client_part_8_train_loss,
                    client_part_8_train_accuracy,
                    client_part_8_per_test_loss,
                    client_part_8_per_test_accuracy,
                    client_part_8_per_train_loss,
                    client_part_8_per_train_accuracy,
                    client_part_12_test_loss,
                    client_part_12_test_accuracy,
                    client_part_12_train_loss,
                    client_part_12_train_accuracy,
                    client_part_12_per_test_loss,
                    client_part_12_per_test_accuracy,
                    client_part_12_per_train_loss,
                    client_part_12_per_train_accuracy,
                    client_part_16_test_loss,
                    client_part_16_test_accuracy,
                    client_part_16_train_loss,
                    client_part_16_train_accuracy,
                    client_part_16_per_test_loss,
                    client_part_16_per_test_accuracy,
                    client_part_16_per_train_loss,
                    client_part_16_per_train_accuracy,
                    client_part_20_test_loss,
                    client_part_20_test_accuracy,
                    client_part_20_train_loss,
                    client_part_20_train_accuracy,
                    client_part_20_per_test_loss,
                    client_part_20_per_test_accuracy,
                    client_part_20_per_train_loss,
                    client_part_20_per_train_accuracy,
                    client_part_40_test_loss,
                    client_part_40_test_accuracy,
                    client_part_40_train_loss,
                    client_part_40_train_accuracy,
                    client_part_40_per_test_loss,
                    client_part_40_per_test_accuracy,
                    client_part_40_per_train_loss,
                    client_part_40_per_train_accuracy,
                    path
                    ):
        
        
        fig, ax = plt.subplots(1,4, figsize=(20,4))

        ax[0].plot(client_part_8_test_loss, label= "Clients=8", color='blue')
        ax[0].plot(client_part_12_test_loss, label= "Clients=12", color='black')
        ax[0].plot(client_part_16_test_loss, label= "Clients=16", color='skyblue')
        ax[0].plot(client_part_20_test_loss, label= "Clients=20", color='green')
        ax[0].plot(client_part_40_test_loss, label= "Clients=40", color='gray')
        ax[0].set_xlabel("Global Iteration")
        ax[0].set_ylabel("Validation Loss (GM)")
        ax[0].set_xticks(range(0, 50, int(50/5)))
        #ax[0].legend(prop={"size":12})
        #ax[0].legend()
        #x1, x2, y1, y2 = 600, 800, 0.15, 2.0  # Adjust these values as needed
        #axins = inset_axes(ax[0], width="50%", height="50%", loc=7)
        #axins.plot(apriori_test_loss)
        #axins.plot(dynamic_test_loss)  
        #axins.set_xlim(x1, x2)
        #axins.set_ylim(y1, y2)
        #axins.indicate_inset_zoom(axins, edgecolor="black")

       # ax[1].plot(Fedavg_gd_test_accuracy, label= "FedAvg+GD")
        #ax[1].plot(Fedavg_sgd_test_accuracy, label= "FedAvg+SGD")
        ax[1].plot(client_part_8_test_accuracy, label= "Clients=8", color='blue')
        ax[1].plot(client_part_12_test_accuracy, label= "Clients=12", color='black')
        ax[1].plot(client_part_16_test_accuracy, label= "Clients=16", color='skyblue')
        ax[1].plot(client_part_20_test_accuracy, label= "Clients=20", color='green')
        ax[1].plot(client_part_40_test_accuracy, label= "Clients=40", color='gray')
        ax[1].set_xlabel("Global Iteration")
        ax[1].set_xticks(range(0, 50, int(50/5)))
        ax[1].set_ylabel("Validation Accuracy (GM)")
        #ax[1].legend(prop={"size":12})
        #ax[1].legend()
        """x1, x2, y1, y2 = 600, 800, 0.8, 0.92  # Adjust these values as needed
        axins = inset_axes(ax[1], width="50%", height="50%", loc=7)
        axins.plot(Fedavg_test_accuracy)
        axins.plot(Fedprox_test_accuracy) 
        axins.plot(Fedmem_test_accuracy) 
        axins.set_xlim(x1, x2)
        axins.set_ylim(y1, y2)
        axins.indicate_inset_zoom(axins, edgecolor="black")
        """
        ax[2].plot(client_part_8_per_test_loss, label= "Clients=8", color='blue')
        ax[2].plot(client_part_12_per_test_loss, label= "Clients=12", color='black')
        ax[2].plot(client_part_16_per_test_loss, label= "Clients=16", color='skyblue')
        ax[2].plot(client_part_20_per_test_loss, label= "Clients=20", color='green')
        ax[2].plot(client_part_40_per_test_loss, label= "Clients=40", color='gray')
        ax[2].set_xlabel("Global Iteration")
        #ax[2].set_xscale('log')
        ax[2].set_ylabel("Validation Loss (PM)")
        #ax[2].set_yscale('log')
        ax[2].set_xticks(range(0, 50, int(50/5)))
        #ax[2].legend(prop={"size":12})
        #ax[2].legend()
        """x1, x2, y1, y2 = 600, 800, 0.1, 0.55  # Adjust these values as needed
        axins = inset_axes(ax[2], width="50%", height="50%", loc=7)
        axins.plot(Fedavg_train_loss, label="FedAvg")
        axins.plot(Fedprox_train_loss, label= "FedProx")
        axins.plot(Fedmem_train_loss, label= "FedMEM(PM)")
        axins.set_xlim(x1, x2)
        axins.set_ylim(y1, y2)
        axins.indicate_inset_zoom(axins, edgecolor="black")
        """
        # ax[3].plot(Fedavg_gd_train_accuracy, label= "FedAvg+GD")
        #ax[3].plot(Fedavg_sgd_train_accuracy, label= "FedAvg+SGD")
        ax[3].plot(client_part_8_per_test_accuracy, label= "Clients=8", color='blue')
        ax[3].plot(client_part_12_per_test_accuracy, label= "Clients=12", color='black')
        ax[3].plot(client_part_16_per_test_accuracy, label= "Clients=16", color='skyblue')
        ax[3].plot(client_part_20_per_test_accuracy, label= "Clients=20", color='green')
        ax[3].plot(client_part_40_per_test_accuracy, label= "Clients=40", color='gray')
        
        ax[3].set_xlabel("Global Iteration")
        ax[3].set_ylabel("Validation Accuracy (PM)")
        ax[3].set_xticks(range(0, 50, int(50/5)))
        #ax[3].legend(prop={"size":12})
        #ax[3].legend()

        """
        x1, x2, y1, y2 = 600, 800, 0.8, 0.98  # Adjust these values as needed
        axins = inset_axes(ax[3], width="50%", height="50%", loc=7)
        axins.plot(Fedavg_train_accuracy)
        axins.plot(Fedprox_train_accuracy) 
        axins.plot(Fedmem_train_accuracy) 
        axins.set_xlim(x1, x2)
        axins.set_ylim(y1, y2)
        axins.indicate_inset_zoom(axins, edgecolor="black")
        """
        handles, labels = ax[3].get_legend_handles_labels()
        fig.legend(handles, labels, loc='upper center', ncol=4, fontsize=12)


        plt.draw()
       
        plt.savefig(path +'convergence.png')

        # Show the graph
        plt.show()

# %%
def plot_precision_recall_f1(client_8_precision, 
                            client_8_recall, 
                            client_8_f1, 
                            client_8_per_precision, 
                            client_8_per_recall, 
                            client_8_per_f1,
                            client_12_precision, 
                            client_12_recall, 
                            client_12_f1,
                            client_12_per_precision, 
                            client_12_per_recall, 
                            client_12_per_f1,
                            client_16_precision, 
                            client_16_recall, 
                            client_16_f1, 
                            client_16_per_precision, 
                            client_16_per_recall, 
                            client_16_per_f1,
                            client_20_precision, 
                            client_20_recall, 
                            client_20_f1,
                            client_20_per_precision, 
                            client_20_per_recall, 
                            client_20_per_f1,
                            client_40_precision, 
                            client_40_recall, 
                            client_40_f1,
                            client_40_per_precision, 
                            client_40_per_recall, 
                            client_40_per_f1,

                            path):
    
    fig, ax = plt.subplots(1,3, figsize=(20,4))

    ax[0].plot(client_8_per_precision, label= "Clients=8", color='blue')
    ax[0].plot(client_12_per_precision, label= "Clients=12", color='black')
    ax[0].plot(client_16_per_precision, label= "Clients=16", color='skyblue')
    ax[0].plot(client_20_per_precision, label= "Clients=20", color='green')
    ax[0].plot(client_40_per_precision, label= "Clients=40", color='gray')
        
    ax[0].set_xlabel("Global Iteration")
    ax[0].set_ylabel("Precisio (PM)")
    ax[0].set_xticks(range(0, 50, int(50/5)))


    ax[1].plot(client_8_per_recall, label= "Clients=8", color='blue')
    ax[1].plot(client_12_per_recall, label= "Clients=12", color='black')
    ax[1].plot(client_16_per_recall, label= "Clients=16", color='skyblue')
    ax[1].plot(client_20_per_recall, label= "Clients=20", color='green')
    ax[1].plot(client_40_per_recall, label= "Clients=40", color='gray')
    ax[1].set_xlabel("Global Iteration")
    ax[1].set_ylabel("Recall (PM)")
    ax[1].set_xticks(range(0, 50, int(50/5)))

    ax[2].plot(client_8_per_f1, label= "Clients=8", color='blue')
    ax[2].plot(client_12_per_f1, label= "Clients=12", color='black')
    ax[2].plot(client_16_per_f1, label= "Clients=16", color='skyblue')
    ax[2].plot(client_20_per_f1, label= "Clients=20", color='green')
    ax[2].plot(client_40_per_f1, label= "Clients=40", color='gray')
        
    ax[2].set_xlabel("Global Iteration")
    ax[2].set_ylabel("F1-score (PM)")
    ax[2].set_xticks(range(0, 50, int(50/5)))
        
    handles, labels = ax[2].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', ncol=4, fontsize=12)


    plt.draw()
       
    plt.savefig(path +'precision_recall_f1.png')

    # Show the graph
    plt.show()

# %%
def print_stats(description, mean_std, file):
    file.write(f"{description} (mean/std) : ({mean_std[0]} / {mean_std[1]})\n")

# %%
def average_result(path,directory_name, client_part):
    
    dir_list = os.listdir(path)

    i=0
    train_loss, train_accuracy, test_loss, test_accuracy = [], [], [], []
    per_train_loss, per_train_accuracy, per_test_loss, per_test_accuracy = [], [], [], []
    per_precision, per_recall, per_f1 = [], [], []
    precision, recall, f1 = [], [], []

    for file_name in dir_list:
         if file_name.endswith(".h5"):
            print(file_name)
            attributes, hf = read_file(path+file_name)

            data = get_data(hf,attributes)
            id=0
            for key in hf.keys():
                attributes.append(key)
                # print("id [",id,"] :", key)
                id+=1

            gtsl = hf.get('global_test_loss')
            gtrl = hf.get('global_train_loss')
            gtsa = hf.get('global_test_accuracy')
            gtra = hf.get('global_train_accuracy')

            ptsl = hf.get('per_test_loss')
            ptrl = hf.get('per_train_loss')
            ptsa = hf.get('per_test_accuracy')
            ptra = hf.get('per_train_accuracy')

            gp = hf.get('global_precision')
            gr = hf.get('global_recall')
            gf1 = hf.get('global_f1score')

            pp = hf.get('per_precision')
            pr = hf.get('per_recall')
            pf1 = hf.get('per_f1score')
            
            test_loss.append(np.array(gtsl).tolist())
            train_loss.append(np.array(gtrl).tolist())
            test_accuracy.append(np.array(gtsa).tolist())
            train_accuracy.append(np.array(gtra).tolist())

            per_test_loss.append(np.array(ptsl).tolist())
            per_train_loss.append(np.array(ptrl).tolist())
            per_test_accuracy.append(np.array(ptsa).tolist())
            per_train_accuracy.append(np.array(ptra).tolist())

            precision.append(np.array(gp).tolist())
            recall.append(np.array(gr).tolist())
            f1.append(np.array(gf1).tolist())

            per_precision.append(np.array(pp).tolist())
            per_recall.append(np.array(pr).tolist())
            per_f1.append(np.array(pf1).tolist())

            
    avg_train_loss = np.array(train_loss)
    avg_test_loss = np.array(test_loss)
    avg_train_accuracy = np.array(train_accuracy)
    avg_test_accuracy = np.array(test_accuracy)


    avg_per_train_loss = np.array(per_train_loss)
    avg_per_test_loss = np.array(per_test_loss)
    avg_per_train_accuracy = np.array(per_train_accuracy)
    avg_per_test_accuracy = np.array(per_test_accuracy)

    avg_precision = np.array(precision)
    avg_recall = np.array(recall)
    avg_f1 = np.array(f1)

    avg_per_precision = np.array(per_precision)
    avg_per_recall = np.array(per_recall)
    avg_per_f1 = np.array(per_f1)


    gtrl_mean = np.mean(avg_train_loss, axis=0)
    gtra_mean = np.mean(avg_train_accuracy, axis=0)
    gtsl_mean = np.mean(avg_test_loss, axis=0)
    gtsa_mean = np.mean(avg_test_accuracy, axis=0)

    ptrl_mean = np.mean(avg_per_train_loss, axis=0)
    ptra_mean = np.mean(avg_per_train_accuracy, axis=0)
    ptsl_mean = np.mean(avg_per_test_loss, axis=0)
    ptsa_mean = np.mean(avg_per_test_accuracy, axis=0)
    print(ptra_mean)

    gp_mean = np.mean(avg_precision, axis=0)
    gr_mean = np.mean(avg_recall, axis=0)
    gf1_mean = np.mean(avg_f1, axis=0)

    pp_mean = np.mean(avg_per_precision, axis=0)
    pr_mean = np.mean(avg_per_recall, axis=0)
    pf1_mean = np.mean(avg_per_f1, axis=0)
    





    gtrl_std = np.std(avg_train_loss, axis=0)
    gtra_std = np.std(avg_train_accuracy, axis=0)
    gtsl_std = np.std(avg_test_loss, axis=0)
    gtsa_std = np.std(avg_test_accuracy, axis=0)

    ptrl_std = np.std(avg_per_train_loss, axis=0)
    ptra_std = np.std(avg_per_train_accuracy, axis=0)
    ptsl_std = np.std(avg_per_test_loss, axis=0)
    ptsa_std = np.std(avg_per_test_accuracy, axis=0)

    gp_std = np.std(avg_precision, axis=0)
    gr_std = np.std(avg_recall, axis=0)
    gf1_std = np.std(avg_f1, axis=0)

    pp_std = np.std(avg_per_precision, axis=0)
    pr_std = np.std(avg_per_recall, axis=0)
    pf1_std = np.std(avg_per_f1, axis=0)
    


    gtrl_mean_std = np.column_stack((gtrl_mean, gtrl_std))
    gtra_mean_std = np.column_stack((gtra_mean, gtra_std))
    gtsl_mean_std = np.column_stack((gtsl_mean, gtsl_std))
    gtsa_mean_std = np.column_stack((gtsa_mean, gtsa_std))

    ptrl_mean_std = np.column_stack((ptrl_mean, ptrl_std))
    ptra_mean_std = np.column_stack((ptra_mean, ptra_std))
    ptsl_mean_std = np.column_stack((ptsl_mean, ptsl_std))
    ptsa_mean_std = np.column_stack((ptsa_mean, ptsa_std))

    gp_mean_std = np.column_stack((gp_mean, gp_std))
    gr_mean_std = np.column_stack((gr_mean, gr_std))
    gf1_mean_std = np.column_stack((gf1_mean, gf1_std))

    pp_mean_std = np.column_stack((pp_mean, pp_std))
    pr_mean_std = np.column_stack((pr_mean, pr_std))
    pf1_mean_std = np.column_stack((pf1_mean, pf1_std))

    training_loss_mean_std = gtrl_mean_std[gtrl_mean_std[:,0].argmin()]
    training_acc_mean_std = gtra_mean_std[gtra_mean_std[:,0].argmax()]
    val_loss_mean_std = gtsl_mean_std[gtsl_mean_std[:,0].argmin()]
    val_acc_mean_std = gtsa_mean_std[gtsa_mean_std[:,0].argmax()]

    per_training_loss_mean_std = ptrl_mean_std[gtrl_mean_std[:,0].argmin()]
    per_training_acc_mean_std = ptra_mean_std[gtra_mean_std[:,0].argmax()]
    per_val_loss_mean_std = ptsl_mean_std[gtsl_mean_std[:,0].argmin()]
    per_val_acc_mean_std = ptsa_mean_std[gtsa_mean_std[:,0].argmax()]

    precision_mean_std = gp_mean_std[gp_mean_std[:,0].argmax()]
    recall_mean_std = gr_mean_std[gr_mean_std[:,0].argmax()]
    f1_mean_std = gf1_mean_std[gf1_mean_std[:,0].argmax()]

    per_precision_mean_std = pp_mean_std[pp_mean_std[:,0].argmax()]
    per_recall_mean_std = pr_mean_std[pr_mean_std[:,0].argmax()]
    per_f1_mean_std = pf1_mean_std[pf1_mean_std[:,0].argmax()]
    
    filename = 'client_part_' + str(client_part)

    with h5py.File(directory_name  + '{}.h5'.format(filename), 'w') as hf:
        hf.create_dataset('avg_training_loss', data=gtrl_mean)
        hf.create_dataset('avg_training_accuracy', data=gtra_mean)
        hf.create_dataset('avg_test_loss', data=gtsl_mean)
        hf.create_dataset('avg_test_accuracy', data=gtsa_mean)
        
        hf.create_dataset('avg_per_training_loss', data=ptrl_mean)
        hf.create_dataset('avg_per_training_accuracy', data=ptra_mean)
        hf.create_dataset('avg_per_test_loss', data=ptsl_mean)
        hf.create_dataset('avg_per_test_accuracy', data=ptsa_mean)

        hf.create_dataset('avg_precision', data=gp_mean)
        hf.create_dataset('avg_recall', data=gr_mean)
        hf.create_dataset('avg_f1', data=gf1_mean)

        hf.create_dataset('avg_per_precision', data=pp_mean)
        hf.create_dataset('avg_per_recall', data=pr_mean)
        hf.create_dataset('avg_per_f1', data=pf1_mean)

        hf.close



    print("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-")
    print(f"Client participation :{client_part}  ")
    print(f"Global training loss (mean/std) : ({training_loss_mean_std[0]} / {training_loss_mean_std[1]})")
    print(f"Global training accuracy (mean/std) : ({training_acc_mean_std[0]} / {training_acc_mean_std[1]})")
    print(f"Global test loss (mean/std) : ({val_loss_mean_std[0]} / {val_loss_mean_std[1]})")
    print(f"Global test accuracy (mean/std) : ({val_acc_mean_std[0]} / {val_acc_mean_std[1]})")
    print("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n")
    print(f"Personalized training loss (mean/std) : ({per_training_loss_mean_std[0]} / {per_training_loss_mean_std[1]})")
    print(f"Personalized training accuracy (mean/std) : ({per_training_acc_mean_std[0]} / {per_training_acc_mean_std[1]})")
    print(f"Personalized test loss (mean/std) : ({per_val_loss_mean_std[0]} / {per_val_loss_mean_std[1]})")
    print(f"Personalized test accuracy (mean/std) : ({per_val_acc_mean_std[0]} / {per_val_acc_mean_std[1]})")  
    print("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n")  
    print(f"Global Precision (mean/std) : ({precision_mean_std[0]} / {precision_mean_std[1]})")
    print(f"Global Recall (mean/std) : ({recall_mean_std[0]} / {recall_mean_std[1]})")
    print(f"Global F1Score (mean/std) : ({f1_mean_std[0]} / {f1_mean_std[1]})")
    print("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n")  
    print(f"Personalized Precision (mean/std) : ({per_precision_mean_std[0]} / {per_precision_mean_std[1]})")
    print(f"Personalized Recall (mean/std) : ({per_recall_mean_std[0]} / {per_recall_mean_std[1]})")
    print(f"Personalized F1Score (mean/std) : ({per_f1_mean_std[0]} / {per_f1_mean_std[1]})")
    print("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n") 

    file_name = str(client_part) + '.txt'
    # Open a file to write
    with open(directory_name + '/' + file_name, 'w') as file:
        file.write("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n")
        file.write(f"Client participation :{client_part}\n")
        print_stats("Global training loss", training_loss_mean_std, file)
        print_stats("Global training accuracy", training_acc_mean_std, file)
        print_stats("Global test loss", val_loss_mean_std, file)
        print_stats("Global test accuracy", val_acc_mean_std, file)
        file.write("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n\n")
        print_stats("Personalized training loss", per_training_loss_mean_std, file)
        print_stats("Personalized training accuracy", per_training_acc_mean_std, file)
        print_stats("Personalized test loss", per_val_loss_mean_std, file)
        print_stats("Personalized test accuracy", per_val_acc_mean_std, file)
        file.write("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n\n")
        print_stats("Global Precision", precision_mean_std, file)
        print_stats("Global Recall", recall_mean_std, file)
        print_stats("Global F1Score", f1_mean_std, file)
        file.write("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n\n")
        print_stats("Personalized Precision", per_precision_mean_std, file)
        print_stats("Personalized Recall", per_recall_mean_std, file)
        print_stats("Personalized F1Score", per_f1_mean_std, file)
        file.write("+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-\n\n")

# %%
"""
Get the average of accuracy and loss
"""

path = "/proj/sourasb-220503/FedMEM/results/ResNet50TL/Fedmem/3/dynamic/40.0/h5/"
directory_name = "/proj/sourasb-220503/FedMEM/results/convergence/participation/3/new/"
average_result(path, directory_name, 40)
# Out:
# _exp_no_2_GR_50_BS_64.h5
# _exp_no_1_GR_50_BS_64.h5
# _exp_no_3_GR_50_BS_64.h5
# _exp_no_0_GR_50_BS_64.h5
# _exp_no_4_GR_50_BS_64.h5
# [0.45608798 0.77476924 0.82108307 0.8256642  0.78636445 0.75800746
#  0.71391185 0.68035745 0.63817919 0.6033237  0.57278831 0.56067495
#  0.55607894 0.55276521 0.55047742 0.55069208 0.5488616  0.54743311
#  0.5483019  0.55022645 0.54895964 0.54844401 0.54756116 0.54900371
#  0.54927223 0.54900371 0.5488616  0.54844401 0.5488616  0.5477685
#  0.5471658  0.54847745 0.5488616  0.54952223 0.54790654 0.54896253
#  0.5488616  0.54896253 0.54738803 0.54804865 0.54837653 0.54729227
#  0.54763413 0.54896253 0.54759294 0.54952223 0.54763413 0.54836628
#  0.54726901 0.54896253]
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Client participation :40
# Global training loss (mean/std) : (1.0537373879551888 / 0.0062386600824459095)
# Global training accuracy (mean/std) : (0.46468023797591484 / 0.016623071212312615)
# ...

# %%
def convergence_analysis(path, acc_file, loss_file):
    dir_list = os.listdir(path)
    
    client_part_8_test_loss = []
    client_part_8_test_accuracy = []
    client_part_8_train_loss = []
    client_part_8_train_accuracy = []
    
    client_part_8_per_test_loss = []
    client_part_8_per_test_accuracy = []
    client_part_8_per_train_loss = []
    client_part_8_per_train_accuracy = []

    client_part_8_precision = []
    client_part_8_recall = []
    client_part_8_f1 = []

    client_part_8_per_precision = []
    client_part_8_per_recall = []
    client_part_8_per_f1 = []

    client_part_12_test_loss = []
    client_part_12_test_accuracy = []
    client_part_12_train_loss = []
    client_part_12_train_accuracy = []

    
    client_part_12_per_test_loss = []
    client_part_12_per_test_accuracy = []
    client_part_12_per_train_loss = []
    client_part_12_per_train_accuracy = []

    client_part_12_precision = []
    client_part_12_recall = []
    client_part_12_f1 = []

    client_part_12_per_precision = []
    client_part_12_per_recall = []
    client_part_12_per_f1 = []


    client_part_16_test_loss = []
    client_part_16_test_accuracy = []
    client_part_16_train_loss = []
    client_part_16_train_accuracy = []
    
    client_part_16_per_test_loss = []
    client_part_16_per_test_accuracy = []
    client_part_16_per_train_loss = []
    client_part_16_per_train_accuracy = []

    client_part_16_precision = []
    client_part_16_recall = []
    client_part_16_f1 = []

    client_part_16_per_precision = []
    client_part_16_per_recall = []
    client_part_16_per_f1 = []

    client_part_20_test_loss = []
    client_part_20_test_accuracy = []
    client_part_20_train_loss = []
    client_part_20_train_accuracy = []
    
    client_part_20_per_test_loss = []
    client_part_20_per_test_accuracy = []
    client_part_20_per_train_loss = []
    client_part_20_per_train_accuracy = []

    client_part_20_precision = []
    client_part_20_recall = []
    client_part_20_f1 = []

    client_part_20_per_precision = []
    client_part_20_per_recall = []
    client_part_20_per_f1 = []

    client_part_40_test_loss = []
    client_part_40_test_accuracy = []
    client_part_40_train_loss = []
    client_part_40_train_accuracy = []
    
    client_part_40_per_test_loss = []
    client_part_40_per_test_accuracy = []
    client_part_40_per_train_loss = []
    client_part_40_per_train_accuracy = []

    client_part_40_precision = []
    client_part_40_recall = []
    client_part_40_f1 = []

    client_part_40_per_precision = []
    client_part_40_per_recall = []
    client_part_40_per_f1 = []

    
    for file_name in dir_list:
        if file_name in ['client_part_8.h5','client_part_12.h5','client_part_16.h5','client_part_20.h5','client_part_40.h5']:
            print(file_name)
            attributes, hf = read_file(path+file_name)

            data = get_data(hf,attributes)
            #id=0
            for key in hf.keys():
                attributes.append(key)
                # print("id [",id,"] :", key)
                #id+=1
            train_loss = hf.get('avg_training_loss')
            train_acc = hf.get('avg_training_accuracy')   
            val_loss = hf.get('avg_test_loss')
            val_acc = hf.get('avg_test_accuracy')
            precision = hf.get('avg_global_precision')
            recall = hf.get('avg_global_recall')
            f1 = hf.get('avg_global_f1score')

            per_train_loss = hf.get('avg_per_train_loss')
            per_train_acc = hf.get('avg_per_training_accuracy')   
            per_val_loss = hf.get('avg_per_test_loss')
            per_val_acc = hf.get('avg_per_test_accuracy')
            per_precision = hf.get('avg_per_precision')
            per_recall = hf.get('avg_per_recall')
            per_f1 = hf.get('avg_per_f1score')

            if file_name == "client_part_8.h5":
                client_part_8_train_loss.append(np.array(train_loss).tolist())
                client_part_8_train_accuracy.append(np.array(train_acc).tolist())
                client_part_8_test_loss.append(np.array(val_loss).tolist())
                client_part_8_test_accuracy.append(np.array(val_acc).tolist())
                client_part_8_per_train_loss.append(np.array(per_train_loss).tolist())
                client_part_8_per_train_accuracy.append(np.array(per_train_acc).tolist())
                client_part_8_per_test_loss.append(np.array(per_val_loss).tolist())
                client_part_8_per_test_accuracy.append(np.array(per_val_acc).tolist())

                client_part_8_precision.append(np.array(precision).tolist())
                client_part_8_recall.append(np.array(recall).tolist())
                client_part_8_f1.append(np.array(f1).tolist())


                client_part_8_per_precision.append(np.array(per_precision).tolist())
                client_part_8_per_recall.append(np.array(per_recall).tolist())
                client_part_8_per_f1.append(np.array(per_f1).tolist())

                    # print(Fedavg_train_loss)
            elif file_name == "client_part_12.h5":

                client_part_12_train_loss.append(np.array(train_loss).tolist())
                client_part_12_train_accuracy.append(np.array(train_acc).tolist())
                client_part_12_test_loss.append(np.array(val_loss).tolist())
                client_part_12_test_accuracy.append(np.array(val_acc).tolist())
                client_part_12_per_train_loss.append(np.array(per_train_loss).tolist())
                client_part_12_per_train_accuracy.append(np.array(per_train_acc).tolist())
                client_part_12_per_test_loss.append(np.array(per_val_loss).tolist())
                client_part_12_per_test_accuracy.append(np.array(per_val_acc).tolist())

                client_part_12_precision.append(np.array(precision).tolist())
                client_part_12_recall.append(np.array(recall).tolist())
                client_part_12_f1.append(np.array(f1).tolist())


                client_part_12_per_precision.append(np.array(per_precision).tolist())
                client_part_12_per_recall.append(np.array(per_recall).tolist())
                client_part_12_per_f1.append(np.array(per_f1).tolist())


            elif file_name == "client_part_16.h5":
                client_part_16_train_loss.append(np.array(train_loss).tolist())
                client_part_16_train_accuracy.append(np.array(train_acc).tolist())
                client_part_16_test_loss.append(np.array(val_loss).tolist())
                client_part_16_test_accuracy.append(np.array(val_acc).tolist())
                client_part_16_per_train_loss.append(np.array(per_train_loss).tolist())
                client_part_16_per_train_accuracy.append(np.array(per_train_acc).tolist())
                client_part_16_per_test_loss.append(np.array(per_val_loss).tolist())
                client_part_16_per_test_accuracy.append(np.array(per_val_acc).tolist())

                client_part_16_precision.append(np.array(precision).tolist())
                client_part_16_recall.append(np.array(recall).tolist())
                client_part_16_f1.append(np.array(f1).tolist())


                client_part_16_per_precision.append(np.array(per_precision).tolist())
                client_part_16_per_recall.append(np.array(per_recall).tolist())
                client_part_16_per_f1.append(np.array(per_f1).tolist())

                    # print(Fedavg_train_loss)
            elif file_name == "client_part_20.h5":

                client_part_20_train_loss.append(np.array(train_loss).tolist())
                client_part_20_train_accuracy.append(np.array(train_acc).tolist())
                client_part_20_test_loss.append(np.array(val_loss).tolist())
                client_part_20_test_accuracy.append(np.array(val_acc).tolist())
                client_part_20_per_train_loss.append(np.array(per_train_loss).tolist())
                client_part_20_per_train_accuracy.append(np.array(per_train_acc).tolist())
                client_part_20_per_test_loss.append(np.array(per_val_loss).tolist())
                client_part_20_per_test_accuracy.append(np.array(per_val_acc).tolist())

                client_part_20_precision.append(np.array(precision).tolist())
                client_part_20_recall.append(np.array(recall).tolist())
                client_part_20_f1.append(np.array(f1).tolist())


                client_part_20_per_precision.append(np.array(per_precision).tolist())
                client_part_20_per_recall.append(np.array(per_recall).tolist())
                client_part_20_per_f1.append(np.array(per_f1).tolist())

            elif file_name == "client_part_40.h5":

                client_part_40_train_loss.append(np.array(train_loss).tolist())
                client_part_40_train_accuracy.append(np.array(train_acc).tolist())
                client_part_40_test_loss.append(np.array(val_loss).tolist())
                client_part_40_test_accuracy.append(np.array(val_acc).tolist())
                client_part_40_per_train_loss.append(np.array(per_train_loss).tolist())
                client_part_40_per_train_accuracy.append(np.array(per_train_acc).tolist())
                client_part_40_per_test_loss.append(np.array(per_val_loss).tolist())
                client_part_40_per_test_accuracy.append(np.array(per_val_acc).tolist())

                client_part_40_precision.append(np.array(precision).tolist())
                client_part_40_recall.append(np.array(recall).tolist())
                client_part_40_f1.append(np.array(f1).tolist())


                client_part_40_per_precision.append(np.array(per_precision).tolist())
                client_part_40_per_recall.append(np.array(per_recall).tolist())
                client_part_40_per_f1.append(np.array(per_f1).tolist())
        
            
    train_loss = {
        'GR' : np.arange(50),
        # 'client_part_8' : client_part_8_train_loss[0][:],
        'client_part_12' : client_part_12_train_loss[0][:],
        'client_part_16' : client_part_16_train_loss[0][:],
        'client_part_20' : client_part_20_train_loss[0][:],
        'client_part_40' : client_part_40_train_loss[0][:],
        'client_part_8p' : client_part_8_per_train_loss[0][:],
        'client_part_12p' : client_part_12_per_train_loss[0][:],
        'client_part_16p' : client_part_16_per_train_loss[0][:],
        'client_part_20p' : client_part_20_per_train_loss[0][:],
        'client_part_40' : client_part_40_per_train_loss[0][:]
    }

    train_acc = {
        'GR' : np.arange(50),
        'client_part_8' : client_part_8_train_accuracy[0][:],
        'client_part_12' : client_part_12_train_accuracy[0][:],
        'client_part_16' : client_part_16_train_accuracy[0][:],
        'client_part_20' : client_part_20_train_accuracy[0][:],
        'client_part_40' : client_part_40_train_accuracy[0][:],
        'client_part_8p' : client_part_8_per_train_accuracy[0][:],
        'client_part_12p' : client_part_12_per_train_accuracy[0][:],
        'client_part_16p' : client_part_16_per_train_accuracy[0][:],
        'client_part_20p' : client_part_20_per_train_accuracy[0][:],
        'client_part_40' : client_part_40_per_train_accuracy[0][:]
    }


    val_loss = {
        'GR' : np.arange(50),
        'client_part_8' : client_part_8_test_loss[0][:],
        'client_part_12' : client_part_12_test_loss[0][:],
        'client_part_16' : client_part_16_test_loss[0][:],
        'client_part_20' : client_part_20_test_loss[0][:],
        'client_part_40' : client_part_40_test_loss[0][:],
        'client_part_8p' : client_part_8_per_test_loss[0][:],
        'client_part_12p' : client_part_12_per_test_loss[0][:],
        'client_part_16p' : client_part_16_per_test_loss[0][:],
        'client_part_20p' : client_part_20_per_test_loss[0][:],
        'client_part_40' : client_part_40_per_test_loss[0][:]
    }


    val_acc = {
        'GR' : np.arange(50),
        'client_part_8' : client_part_8_test_accuracy[0][:],
        'client_part_12' : client_part_12_test_accuracy[0][:],
        'client_part_16' : client_part_16_test_accuracy[0][:],
        'client_part_20' : client_part_20_test_accuracy[0][:],
        'client_part_40' : client_part_40_test_accuracy[0][:],
        'client_part_8p' : client_part_8_per_test_accuracy[0][:],
        'client_part_12p' : client_part_12_per_test_accuracy[0][:],
        'client_part_16p' : client_part_16_per_test_accuracy[0][:],
        'client_part_20p' : client_part_20_per_test_accuracy[0][:],
        'client_part_40' : client_part_40_per_test_accuracy[0][:]
    }

    precision = {

        'GR' : np.arange(50),
        'client_part_8' : client_part_8_precision[0][:],
        'client_part_12' : client_part_12_precision[0][:],
        'client_part_16' : client_part_16_precision[0][:],
        'client_part_20' : client_part_20_precision[0][:],
        'client_part_40' : client_part_40_precision[0][:],
        'client_part_8p' : client_part_8_per_precision[0][:],
        'client_part_12p' : client_part_12_per_precision[0][:],
        'client_part_16p' : client_part_16_per_precision[0][:],
        'client_part_20p' : client_part_20_per_precision[0][:],
        'client_part_40' : client_part_40_per_precision[0][:]
    }
    recall = {

        
        'GR' : np.arange(50),
        'client_part_8' : client_part_8_recall[0][:],
        'client_part_12' : client_part_12_recall[0][:],
        'client_part_16' : client_part_16_recall[0][:],
        'client_part_20' : client_part_20_recall[0][:],
        'client_part_40' : client_part_40_recall[0][:],
        'client_part_8p' : client_part_8_per_recall[0][:],
        'client_part_12p' : client_part_12_per_recall[0][:],
        'client_part_16p' : client_part_16_per_recall[0][:],
        'client_part_20p' : client_part_20_per_recall[0][:],
        'client_part_40' : client_part_40_per_recall[0][:]
    }

    f1 = {

        'GR' : np.arange(50),
        'client_part_8' : client_part_8_f1[0][:],
        'client_part_12' : client_part_12_f1[0][:],
        'client_part_16' : client_part_16_f1[0][:],
        'client_part_20' : client_part_20_f1[0][:],
        'client_part_40' : client_part_40_f1[0][:],
        'client_part_8p' : client_part_8_per_f1[0][:],
        'client_part_12p' : client_part_12_per_f1[0][:],
        'client_part_16p' : client_part_16_per_f1[0][:],
        'client_part_20p' : client_part_20_per_f1[0][:],
        'client_part_40' : client_part_40_per_f1[0][:]

    }

    
    df_train_loss = pd.DataFrame(train_loss)
    df_train_acc = pd.DataFrame(train_acc)
    df_val_loss = pd.DataFrame(val_loss)
    df_val_acc = pd.DataFrame(val_acc)

    df_precision = pd.DataFrame(precision)
    df_recall = pd.DataFrame(recall)
    df_f1 = pd.DataFrame(f1)



    csv_train_acc_path = path + "train_" + acc_file +".csv"
    csv_train_loss_path = path + "train_" + loss_file +".csv"
    csv_val_acc_path = path + "test_" + acc_file +".csv"
    csv_val_loss_path = path + "test_" +loss_file +".csv"
    
    csv_precision_path = path + "precision.csv"
    csv_recall_path = path + "recall.csv"
    csv_f1_path = path + "f1.csv"
    
    
    txt_train_acc_path = path + "train_" + acc_file +".txt"
    txt_train_loss_path = path +  "train_" + loss_file +".txt"
    txt_val_acc_path = path + "test_" + acc_file +".txt"
    txt_val_loss_path = path + "test_" + loss_file +".txt"

    txt_precision_path = path + "precision.txt"
    txt_recall_path = path + "recall.txt"
    txt_f1_path = path + "f1.txt"

    df_train_acc.to_csv(csv_train_acc_path, index=False)
    df_train_loss.to_csv(csv_train_loss_path, index=False)
    df_val_acc.to_csv(csv_val_acc_path, index=False)
    df_val_loss.to_csv(csv_val_loss_path, index=False)
    df_precision.to_csv(csv_precision_path, index=False)
    df_recall.to_csv(csv_recall_path, index=False)
    df_f1.to_csv(csv_f1_path, index=False)
    
    convert_csv_to_txt(csv_train_acc_path,txt_train_acc_path)
    convert_csv_to_txt(csv_train_loss_path,txt_train_loss_path)
    convert_csv_to_txt(csv_val_acc_path,txt_val_acc_path)
    convert_csv_to_txt(csv_val_loss_path,txt_val_loss_path)
    
    convert_csv_to_txt(csv_precision_path,txt_precision_path)
    convert_csv_to_txt(csv_recall_path,txt_recall_path)
    convert_csv_to_txt(csv_f1_path,txt_f1_path)

    plot_convergence(client_part_8_test_loss[0],
                    client_part_8_test_accuracy[0],
                    client_part_8_train_loss[0],
                    client_part_8_train_accuracy[0],
                    client_part_8_per_test_loss[0],
                    client_part_8_per_test_accuracy[0],
                    client_part_8_per_train_loss[0],
                    client_part_8_per_train_accuracy[0],
                    client_part_12_test_loss[0],
                    client_part_12_test_accuracy[0],
                    client_part_12_train_loss[0],
                    client_part_12_train_accuracy[0],
                    client_part_12_per_test_loss[0],
                    client_part_12_per_test_accuracy[0],
                    client_part_12_per_train_loss[0],
                    client_part_12_per_train_accuracy[0],
                    client_part_16_test_loss[0],
                    client_part_16_test_accuracy[0],
                    client_part_16_train_loss[0],
                    client_part_16_train_accuracy[0],
                    client_part_16_per_test_loss[0],
                    client_part_16_per_test_accuracy[0],
                    client_part_16_per_train_loss[0],
                    client_part_16_per_train_accuracy[0],
                    client_part_20_test_loss[0],
                    client_part_20_test_accuracy[0],
                    client_part_20_train_loss[0],
                    client_part_20_train_accuracy[0],
                    client_part_20_per_test_loss[0],
                    client_part_20_per_test_accuracy[0],
                    client_part_20_per_train_loss[0],
                    client_part_20_per_train_accuracy[0],
                    client_part_40_test_loss[0],
                    client_part_40_test_accuracy[0],
                    client_part_40_train_loss[0],
                    client_part_40_train_accuracy[0],
                    client_part_40_per_test_loss[0],
                    client_part_40_per_test_accuracy[0],
                    client_part_40_per_train_loss[0],
                    client_part_40_per_train_accuracy[0],
                    path)

    plot_precision_recall_f1(client_part_8_precision[0], client_part_8_recall[0], client_part_8_f1[0], client_part_8_per_precision[0], client_part_8_per_recall[0], client_part_8_per_f1[0],
                             client_part_12_precision[0], client_part_12_recall[0], client_part_12_f1[0], client_part_12_per_precision[0], client_part_12_per_recall[0], client_part_12_per_f1[0],
                             client_part_16_precision[0], client_part_16_recall[0], client_part_16_f1[0], client_part_16_per_precision[0], client_part_16_per_recall[0], client_part_16_per_f1[0],
                             client_part_20_precision[0], client_part_20_recall[0], client_part_20_f1[0], client_part_20_per_precision[0], client_part_20_per_recall[0], client_part_20_per_f1[0],
                             client_part_40_precision[0], client_part_40_recall[0], client_part_40_f1[0], client_part_40_per_precision[0], client_part_40_per_recall[0], client_part_40_per_f1[0],
                             path)

# %%
path = "/proj/sourasb-220503/FedMEM/results/convergence/participation/3/"
acc_file = "accuracy"
loss_file = "loss"

convergence_analysis(path, acc_file, loss_file)
# Out:
# client_part_16.h5
# client_part_8.h5
# client_part_40.h5
# client_part_12.h5
# client_part_20.h5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 acc_file = "accuracy"
#       3 loss_file = "loss"
# ----> 5 convergence_analysis(path, acc_file, loss_file)
#
# Cell In[14], line 233, in convergence_analysis(path, acc_file, loss_file)
#     222             client_part_40_per_recall.append(np.array(per_recall).tolist())
#     223             client_part_40_per_f1.append(np.array(per_f1).tolist())
#     226 train_loss = {
#     227     'GR' : np.arange(50),
#     228     'client_part_8' : client_part_8_train_loss[0][:],
#     229     'client_part_12' : client_part_12_train_loss[0][:],
#     230     'client_part_16' : client_part_16_train_loss[0][:],
#     231     'client_part_20' : client_part_20_train_loss[0][:],
# ...
